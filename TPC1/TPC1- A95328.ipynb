# %%
import random
def fósforos():
        n=21
        ordem=input("Pretende jogar primeiro? Sim(s) ou Não(n):")
        if ordem=="Sim" or ordem=="s" or ordem=="sim" or ordem=="S":
            while n >1:
                jogada=int(input("Quantos fósforos quer tirar? 1, 2, 3, 4?"))
                if jogada>=1 and jogada<=4:
                    n=n-jogada
                    print("Restam", n, "fósforos!")
                    if jogada==1:
                        n=n-4
                        print("O computador retira 4 fósforos.")
                        print("Restam", n, "fósforos!")
                    if jogada==2:
                        n=n-3
                        print("O computador retira 3 fósforos.")
                        print("Restam", n, "fósforos!")
                    if jogada==3:
                        n=n-2
                        print("O computador retira 2 fósforos. ")
                        print("Restam", n, "fósforos!")    
                    if jogada==4:
                        n=n-1
                        print("O computador retira 1 fósforo. ")
                        print("Restam", n, "fósforo!")
                if jogada<1 or jogada>4:
                    print("Erro. Retire 1, 2, 3 ou 4 fósforos!")
                
            print("Fim do jogo. Você perdeu! :(")  
        if ordem=="Não" or ordem=="não" or ordem=="n" or ordem=="N":
            jogada_cpu=random.randint(1,4)
            n=n-jogada_cpu
            print("O computador retira", jogada_cpu, "fósforos.")
            print("Restam", n, "fósforos!")
            while n>1:
                jogada=int(input("Quantos fósforos quer tirar? 1, 2, 3, 4?"))
                if jogada>=1 and jogada<=4:    
                    n=n-jogada
                    print("Restam", n, "fósforos!")   
                    if n==1:
                        print("Você ganhou! Parabéns!")
                    if n==2:
                        jogada_cpu=1
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                        print("Fim do jogo. Você perdeu! :(")
                    if n==3:
                        jogada_cpu=2
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                        print("O Jogador perdeu!")
                    if n==4:
                        jogada_cpu=3
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                        print("O Jogador perdeu!")
                    if n==5:
                        jogada_cpu=4
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                        print("O Jogador perdeu!")
                    if n==6:
                        jogada_cpu=random.randint(1,4)
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==7:
                        jogada_cpu=1
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==8:
                        jogada_cpu=2
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==9:
                        jogada_cpu=3
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==10:
                        jogada_cpu=4
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==11:
                        jogada_cpu=random.randint(1,4)
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==12:
                        jogada_cpu=1
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==13:
                        jogada_cpu=2
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==14:
                        jogada_cpu=3
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==15:
                        jogada_cpu=4
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==16:
                        jogada_cpu=random.randint(1,4)
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==17:
                        jogada_cpu=1
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==18:
                        jogada_cpu=2
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==19:
                        jogada_cpu=3
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                    if n==20:
                        jogada_cpu=4
                        n=n-jogada_cpu
                        print("O computador retira", jogada_cpu, "fósforos.")
                        print("Restam", n, "fósforos!")
                if jogada<1 or jogada>4:
                    print("Erro. Retire 1, 2, 3 ou 4 fósforos!")
fósforos()
